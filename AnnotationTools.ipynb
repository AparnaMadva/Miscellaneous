# %% [markdown]
# <a href="https://colab.research.google.com/github/AparnaMadva/Miscellaneous/blob/main/AnnotationTools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### doccano

# %% [markdown]
# [reference](https://newscatcherapi.com/blog/top-6-text-annotation-tools)

# %%
# !pip install doccano
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 26.0 MB 42.2 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 29.2 MB/s
# ...
#      |████████████████████████████████| 80 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 11.4 MB/s
# ...
#      |████████████████████████████████| 87 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 597 kB/s
# ...
#      |████████████████████████████████| 405 kB 28.4 MB/s
# ...
#      |████████████████████████████████| 92 kB 403 kB/s
# ...
#      |████████████████████████████████| 79 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 57 kB 662 kB/s
# ...
#      |████████████████████████████████| 193 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 132 kB 52.9 MB/s
# ...
#      |████████████████████████████████| 189 kB 56.7 MB/s
# ...
#      |████████████████████████████████| 89 kB 8.2 MB/s
# ...

# %%
# Initialize the database
! doccano init
# Create a superuser
! doccano createuser --username admin --password pass
# Start the webserver
! doccano webserver --port 8000
# Out:
# Setup Database.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/backend/manage.py", line 15, in <module>
#     execute_from_command_line(sys.argv)
#   File "/usr/local/lib/python3.7/dist-packages/django/core/management/__init__.py", line 419, in execute_from_command_line
#     utility.execute()
#   File "/usr/local/lib/python3.7/dist-packages/django/core/management/__init__.py", line 395, in execute
#     django.setup()
#   File "/usr/local/lib/python3.7/dist-packages/django/__init__.py", line 24, in setup
#     apps.populate(settings.INSTALLED_APPS)
#   File "/usr/local/lib/python3.7/dist-packages/django/apps/registry.py", line 114, in populate
#     app_config.import_models()
#   File "/usr/local/lib/python3.7/dist-packages/django/apps/config.py", line 301, in import_models
#     self.models_module = import_module(models_module_name)
#   File "/usr/lib/python3.7/importlib/__init__.py", line 127, in import_module
# ...

# %%
! doccano task
# Out:
# Starting task queue.
# Traceback (most recent call last):
#   File "/usr/local/bin/doccano", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/backend/cli.py", line 133, in main
#     args.handler(args)
#   File "/usr/local/lib/python3.7/dist-packages/backend/cli.py", line 92, in command_run_task_queue
#     app.worker_main(argv=argv)
#   File "/usr/local/lib/python3.7/dist-packages/celery/app/base.py", line 391, in worker_main
#     self.start(argv=argv)
#   File "/usr/local/lib/python3.7/dist-packages/celery/app/base.py", line 371, in start
#     celery.main(args=argv, standalone_mode=False)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1055, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1657, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.7/dist-packages/click/core.py", line 1404, in invoke
# ...

# %% [markdown]
# #### streamlit

# %% [markdown]
# [source](https://github.com/mrm8488/shared_colab_notebooks/blob/master/Create_streamlit_app.ipynb)

# %%
# !pip install -q streamlit
# Out:
#      |████████████████████████████████| 9.2 MB 5.5 MB/s
#      |████████████████████████████████| 4.7 MB 45.2 MB/s
#      |████████████████████████████████| 164 kB 51.7 MB/s
#      |████████████████████████████████| 182 kB 60.8 MB/s
#      |████████████████████████████████| 237 kB 44.1 MB/s
#      |████████████████████████████████| 78 kB 7.1 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#      |████████████████████████████████| 51 kB 7.0 MB/s
# ...

# %%
# %%writefile app.py
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)
# Out:
# Writing app.py

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.203s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.69s
# your url is: https://full-brooms-behave-34-121-41-119.loca.lt
# ^C

# %% [markdown]
# #### pywebio

# %% [markdown]
# [deployed app](https://medium.com/@kamendamov/developing-and-deploying-a-heart-disease-classification-app-using-pywebio-44d157a1d4e2)
#   [simple app](https://www.analyticsvidhya.com/blog/2021/04/the-easiest-way-to-deploy-machine-learning-models-pywebio/)

# %%
# !pip install pywebio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 471 kB 5.6 MB/s
# ...
#   Created wheel for pywebio: filename=pywebio-1.7.0-py3-none-any.whl size=482955 sha256=ecf5954fc080b0ee0780f242010e70ec5d82f586256db89716fc181621b39ea0
#   Stored in directory: /root/.cache/pip/wheels/48/f0/16/8a1b7e2aa8bca051b314d15797ea50f2ca56872ef2358cbdd2
# Successfully built pywebio
# ...

# %%
from pywebio.input import input_group, input, NUMBER
from pywebio.output import put_text
from pywebio.exceptions import SessionClosedException

# %%
def demo():
    inputs = input_group("Salary Prediction", [
        input("Enter your age: ", type=NUMBER, name='age'),
        input("Enter your years of experience: ", type=NUMBER, name="year_exp")
    ])

    if (inputs["age"] >= 16 and inputs["age"] <=20) and (inputs["year_exp"] <=1):
        put_text("Your Expected Salary: {}".format(10000))
    elif (inputs["age"] >= 21 and inputs["age"] <=26) and (inputs["year_exp"] >= 2 and inputs["year_exp"] <5):
        put_text("Your Expected Salary: {}".format(40000))
    elif (inputs["age"] >= 27) and (inputs["year_exp"] >=5):
        put_text("Your Expected Salary: {}".format(90000))
    else:
        put_text("Not in scoped rules!")

# %%
if __name__ == "__main__":
    try:
        demo()
    except SessionClosedException:
        print("The session was closed unexpectedly")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-43a3b04e6607> in <module>
#       1 if __name__ == "__main__":
#       2     try:
# ----> 3         demo()
#       4     except SessionClosedException:
#       5         print("The session was closed unexpectedly")
#
# <ipython-input-9-af3eb9b07abb> in demo()
#       1 def demo():
#       2     inputs = input_group("Salary Prediction", [
# ----> 3         input("Enter your age: ", type=NUMBER, name='age'),
#       4         input("Enter your years of experience: ", type=NUMBER, name="year_exp")
#       5     ])
#
# /usr/local/lib/python3.7/dist-packages/pywebio/input.py in input(label, type, validate, name, value, action, onchange, placeholder, required, readonly, datalist, help_text, **other_html_attrs)
#     258         return d
#     259
# ...
